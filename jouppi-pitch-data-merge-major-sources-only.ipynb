# %%
import pandas as pd
from plotnine import *

# importing statsmodels (for linear regression in python)
import statsmodels.formula.api as smf

from datetime import date
today = date.today()
today = pd.to_datetime(today)
import numpy as np
import re
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
pd.set_option("display.max_columns",None)

# %% [markdown]
# ## Load Data

# %% [markdown]
# #### Michigan air polluter documents & permit data
# These are violation notices, activity reports (inspection), compliance evaluations etc...

# %%
doc_df = pd.read_csv("EGLE-AQD-documents.csv")

# %%
doc_df.head()
# Out:
#    source_id doc_type      date  \
# 0      N8277      ACO  20151217
# 1      N8274      ACO  20151217
# 2  U04060035      SAR  20190716
# 3  U04060035      SAR  20200507
# 4      N7824      FCE  20160525
#
#                                              doc_url
# 0  https://www.egle.state.mi.us/aps/downloads/srn...
# 1  https://www.egle.state.mi.us/aps/downloads/srn...
# 2  https://www.egle.state.mi.us/aps/downloads/srn...
# 3  https://www.egle.state.mi.us/aps/downloads/srn...
# 4  https://www.egle.state.mi.us/aps/downloads/srn...

# %%
pti_df = pd.read_csv("ptis-address-clean-042722.csv")
pti_df.head()
# Out:
#                   company    srn              address    city zip_code  \
# 0     MENASHA CORPORATION  A0023  320 N FARMER STREET  OTSEGO    49078
# 1     MENASHA CORPORATION  A0023  320 N FARMER STREET  OTSEGO    49078
# 2       OTSEGO PAPER, INC  A0023  320 N FARMER STREET  OTSEGO    49078
# 3       OTSEGO PAPER, INC  A0023  320 N FARMER STREET  OTSEGO    49078
# 4  SODUS HARD CHROME, INC  A0083     3085 YORE AVENUE   SODUS    49126
#
#     county  pti_no.  approved            notes  flag  \
# 0  ALLEGAN  152-96B   4/12/01  Rolled into ROP     0
# 1  ALLEGAN  222-94A  10/18/02  Rolled into ROP     0
# 2  ALLEGAN   60-03A   5/14/07  Rolled into ROP     0
# 3  ALLEGAN  193-19A   4/22/21  Rolled into ROP     0
# 4  BERRIEN    2-00A   1/14/15              NaN     0
#
#                             full_address
# 0  320 N FARMER STREET, OTSEGO, MI 49078
# 1  320 N FARMER STREET, OTSEGO, MI 49078
# 2  320 N FARMER STREET, OTSEGO, MI 49078
# 3  320 N FARMER STREET, OTSEGO, MI 49078
# 4      3085 YORE AVENUE, SODUS, MI 49126

# %%
# Looking for sources that have "Rolled into ROP" in the notes, because those are Major Sources
major_sources = pti_df.query('notes.str.contains("ROP",na=False)')

# %%
major_sources.approved = pd.to_datetime(major_sources.approved,format="%m/%d/%y")
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
major_sources.head()
# Out:
#                    company    srn              address            city  \
# 0      MENASHA CORPORATION  A0023  320 N FARMER STREET          OTSEGO
# 1      MENASHA CORPORATION  A0023  320 N FARMER STREET          OTSEGO
# 2        OTSEGO PAPER, INC  A0023  320 N FARMER STREET          OTSEGO
# 3        OTSEGO PAPER, INC  A0023  320 N FARMER STREET          OTSEGO
# 32  ESCANABA PAPER COMPANY  A0884    SEC 1, T39N, R23W  WELLS TOWNSHIP
#
#    zip_code   county  pti_no.   approved            notes  flag  \
# 0     49078  ALLEGAN  152-96B 2001-04-12  Rolled into ROP     0
# 1     49078  ALLEGAN  222-94A 2002-10-18  Rolled into ROP     0
# 2     49078  ALLEGAN   60-03A 2007-05-14  Rolled into ROP     0
# 3     49078  ALLEGAN  193-19A 2021-04-22  Rolled into ROP     0
# 32    49829    DELTA   16-70N 2001-03-16  Rolled into ROP     0
#
#                                    full_address
# 0         320 N FARMER STREET, OTSEGO, MI 49078
# 1         320 N FARMER STREET, OTSEGO, MI 49078
# 2         320 N FARMER STREET, OTSEGO, MI 49078
# 3         320 N FARMER STREET, OTSEGO, MI 49078
# 32  SEC 1, T39N, R23W, WELLS TOWNSHIP, MI 49829

# %%
major_sources.zip_code = major_sources.zip_code.astype("str").str[:5]
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Filtering out duplicate records for sources, unless that source has a building in a different zip code.
# Saving the oldest permit on file
major_sources = major_sources.sort_values(['srn','approved']).drop_duplicates(subset=['srn','zip_code'])

# %%
fixed_zips = {
    "49005":"49006",
    "48674":"48640",
    "48686":"48640",
    "48121":"48120",
    "48901":"48910",
    "48795":"48759",
    "48824":"48910",
    "48090":"48092",
    "48859":"48858",
    "49937":"49337",
    "49041":"49048",
    "49152":"49512"
    
}

# %%
major_sources = major_sources.replace({"zip_code": fixed_zips})

# %%
# List of major sources
major_srn = major_sources.srn.to_list()

# %%
# Filter doc df to look at only facilities that are major polluters
major_doc_df = doc_df[doc_df.source_id.isin(major_srn)]
major_doc_df
# Out:
#       source_id doc_type      date  \
# 96        B6636      FCE  20200928
# 97        B6636      RVN  20191003
# 98        B6636      RVN  20200831
# 99        B6636      SAR  20200130
# 100       B6636     TEST  20130924
# ...         ...      ...       ...
# 18582     A0023     TEST  20220325
# 18583     B2796     TEST  20220317
# 18584     N2901      FCE  20220113
# 18585     N2901      SAR  20220113
# 18586     N2901     TEST  20220310
#
#                                                  doc_url
# 96     https://www.egle.state.mi.us/aps/downloads/srn...
# 97     https://www.egle.state.mi.us/aps/downloads/srn...
# 98     https://www.egle.state.mi.us/aps/downloads/srn...
# 99     https://www.egle.state.mi.us/aps/downloads/srn...
# 100    https://www.egle.state.mi.us/aps/downloads/srn...
# ...                                                  ...
# 18582  https://www.egle.state.mi.us/aps/downloads/srn...
# 18583  https://www.egle.state.mi.us/aps/downloads/srn...
# 18584  https://www.egle.state.mi.us/aps/downloads/srn...
# 18585  https://www.egle.state.mi.us/aps/downloads/srn...
# 18586  https://www.egle.state.mi.us/aps/downloads/srn...
#
# [5320 rows x 4 columns]

# %%
major_sources['oldest_permit_age'] = today - major_sources.approved
major_sources['oldest_permit_age'] = (major_sources.oldest_permit_age/np.timedelta64(1, 'Y')).round(2)

# %%
major_sources
# Out:
#                          company    srn                address           city  \
# 0            MENASHA CORPORATION  A0023    320 N FARMER STREET         OTSEGO
# 43            MEAD PAPER COMPANY  A0884   7100 COUNTY ROAD 426       ESCANABA
# 70    GENERAL MOTORS CORPORATION  A1641    920 TOWNSEND STREET        LANSING
# 81                   KALSEC, INC  A1991     3713 W MAIN STREET      KALAMAZOO
# 126      E I DUPONT DE NEMOURS &  A3569  400 GROESBECK HIGHWAY  MOUNT CLEMENS
# ...                          ...    ...                    ...            ...
# 4621    KAWASAKI MOTORS CORP USA  P0677    5080 36TH STREET SE   GRAND RAPIDS
# 4648   TOEFCO ENGINEERED COATING  P0708  1919 INDUSTRIAL DRIVE          NILES
# 4816                TRINSEO, LLC  P1025          433W BUILDING        MIDLAND
# 4817    DDP SPECIALTY ELECTRONIC  P1027    3400 S SAGINAW ROAD        MIDLAND
# 4818    DDP SPECIALTY ELECTRONIC  P1027           954 BUILDING        MIDLAND
#
#      zip_code     county  pti_no.   approved            notes  flag  \
# 0       49078    ALLEGAN  152-96B 2001-04-12  Rolled into ROP     0
# 43      49829      DELTA  800-88A 1998-04-23  Rolled into ROP     0
# 70      48933     INGHAM   69-84A 2000-12-19  Rolled into ROP     0
# 81      49006  KALAMAZOO  104-95A 1997-01-16  Rolled into ROP     0
# 126     48043     MACOMB  646-85A 1997-01-22  Rolled into ROP     0
# ...       ...        ...      ...        ...              ...   ...
# 4621    49512       KENT   230-15 2016-03-10  Rolled into ROP     0
# 4648    49120    BERRIEN    86-16 2016-07-22  Rolled into ROP     0
# 4816    48667    MIDLAND    33-16 2016-04-14  Rolled into ROP     0
# 4817    48667    MIDLAND   167-19 2020-01-27  Rolled into ROP     0
# 4818    48640    MIDLAND   159-19 2020-03-23  Rolled into ROP     0
#
#                                         full_address  oldest_permit_age
# 0              320 N FARMER STREET, OTSEGO, MI 49078              21.05
# 43          7100 COUNTY ROAD 426, ESCANABA, MI 49829              24.02
# 70            920 TOWNSEND STREET, LANSING, MI 48933              21.36
# 81           3713 W MAIN STREET, KALAMAZOO, MI 49005              25.28
# 126   400 GROESBECK HIGHWAY, MOUNT CLEMENS, MI 48043              25.27
# ...                                              ...                ...
# 4621     5080 36TH STREET SE, GRAND RAPIDS, MI 49152               6.14
# 4648          1919 INDUSTRIAL DRIVE, NILES, MI 49120               5.77
# 4816                433W BUILDING, MIDLAND, MI 48667               6.04
# 4817          3400 S SAGINAW ROAD, MIDLAND, MI 48667               2.26
# 4818                 954 BUILDING, MIDLAND, MI 48674               2.10
#
# [285 rows x 12 columns]

# %%
# I only have 9 years worth of data so if a permit is longer than 9 years 
# we are going to just say 9 to keep the rate consistent with the data
def years_convert(years):
    if years > 9:
        return 9.0
    else: 
        return years

# %%
major_sources['oldest_permit_age_converted'] = major_sources.oldest_permit_age.apply(years_convert)

# %%
major_sources
# Out:
#                          company    srn                address           city  \
# 0            MENASHA CORPORATION  A0023    320 N FARMER STREET         OTSEGO
# 43            MEAD PAPER COMPANY  A0884   7100 COUNTY ROAD 426       ESCANABA
# 70    GENERAL MOTORS CORPORATION  A1641    920 TOWNSEND STREET        LANSING
# 81                   KALSEC, INC  A1991     3713 W MAIN STREET      KALAMAZOO
# 126      E I DUPONT DE NEMOURS &  A3569  400 GROESBECK HIGHWAY  MOUNT CLEMENS
# ...                          ...    ...                    ...            ...
# 4621    KAWASAKI MOTORS CORP USA  P0677    5080 36TH STREET SE   GRAND RAPIDS
# 4648   TOEFCO ENGINEERED COATING  P0708  1919 INDUSTRIAL DRIVE          NILES
# 4816                TRINSEO, LLC  P1025          433W BUILDING        MIDLAND
# 4817    DDP SPECIALTY ELECTRONIC  P1027    3400 S SAGINAW ROAD        MIDLAND
# 4818    DDP SPECIALTY ELECTRONIC  P1027           954 BUILDING        MIDLAND
#
#      zip_code     county  pti_no.   approved            notes  flag  \
# 0       49078    ALLEGAN  152-96B 2001-04-12  Rolled into ROP     0
# 43      49829      DELTA  800-88A 1998-04-23  Rolled into ROP     0
# 70      48933     INGHAM   69-84A 2000-12-19  Rolled into ROP     0
# 81      49006  KALAMAZOO  104-95A 1997-01-16  Rolled into ROP     0
# 126     48043     MACOMB  646-85A 1997-01-22  Rolled into ROP     0
# ...       ...        ...      ...        ...              ...   ...
# 4621    49512       KENT   230-15 2016-03-10  Rolled into ROP     0
# 4648    49120    BERRIEN    86-16 2016-07-22  Rolled into ROP     0
# 4816    48667    MIDLAND    33-16 2016-04-14  Rolled into ROP     0
# 4817    48667    MIDLAND   167-19 2020-01-27  Rolled into ROP     0
# 4818    48640    MIDLAND   159-19 2020-03-23  Rolled into ROP     0
#
#                                         full_address  oldest_permit_age  \
# 0              320 N FARMER STREET, OTSEGO, MI 49078              21.05
# 43          7100 COUNTY ROAD 426, ESCANABA, MI 49829              24.02
# 70            920 TOWNSEND STREET, LANSING, MI 48933              21.36
# 81           3713 W MAIN STREET, KALAMAZOO, MI 49005              25.28
# 126   400 GROESBECK HIGHWAY, MOUNT CLEMENS, MI 48043              25.27
# ...                                              ...                ...
# 4621     5080 36TH STREET SE, GRAND RAPIDS, MI 49152               6.14
# 4648          1919 INDUSTRIAL DRIVE, NILES, MI 49120               5.77
# 4816                433W BUILDING, MIDLAND, MI 48667               6.04
# 4817          3400 S SAGINAW ROAD, MIDLAND, MI 48667               2.26
# 4818                 954 BUILDING, MIDLAND, MI 48674               2.10
#
#       oldest_permit_age_converted
# 0                            9.00
# 43                           9.00
# 70                           9.00
# 81                           9.00
# 126                          9.00
# ...                           ...
# 4621                         6.14
# 4648                         5.77
# 4816                         6.04
# 4817                         2.26
# 4818                         2.10
#
# [285 rows x 13 columns]

# %%
major_doc_df.doc_type = major_doc_df.doc_type.str.replace("FCE1","FCE").str.replace("FCE2","FCE")
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def sar_clean(doc_type):
    query = re.findall(r"SAR",doc_type)
    if len(query) > 0:
        return "SAR"
    else:
        return doc_type

# %%
def vn_clean(doc_type):
    query = re.findall(r"^VN",doc_type)
    if len(query) > 0:
        return "VN"
    else:
        return doc_type

# %%
major_doc_df.doc_type = major_doc_df.doc_type.astype("str")

# %%
major_doc_df.doc_type = major_doc_df.doc_type.apply(sar_clean)

# %%
major_doc_df.doc_type = major_doc_df.doc_type.apply(vn_clean)

# %%
major_doc_df.date = pd.to_datetime(doc_df.date, format="%Y%m%d", errors='coerce')
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
major_doc_df
# Out:
#       source_id doc_type       date  \
# 96        B6636      FCE 2020-09-28
# 97        B6636      RVN 2019-10-03
# 98        B6636      RVN 2020-08-31
# 99        B6636      SAR 2020-01-30
# 100       B6636     TEST 2013-09-24
# ...         ...      ...        ...
# 18582     A0023     TEST 2022-03-25
# 18583     B2796     TEST 2022-03-17
# 18584     N2901      FCE 2022-01-13
# 18585     N2901      SAR 2022-01-13
# 18586     N2901     TEST 2022-03-10
#
#                                                  doc_url
# 96     https://www.egle.state.mi.us/aps/downloads/srn...
# 97     https://www.egle.state.mi.us/aps/downloads/srn...
# 98     https://www.egle.state.mi.us/aps/downloads/srn...
# 99     https://www.egle.state.mi.us/aps/downloads/srn...
# 100    https://www.egle.state.mi.us/aps/downloads/srn...
# ...                                                  ...
# 18582  https://www.egle.state.mi.us/aps/downloads/srn...
# 18583  https://www.egle.state.mi.us/aps/downloads/srn...
# 18584  https://www.egle.state.mi.us/aps/downloads/srn...
# 18585  https://www.egle.state.mi.us/aps/downloads/srn...
# 18586  https://www.egle.state.mi.us/aps/downloads/srn...
#
# [5320 rows x 4 columns]

# %%
most_recent_docs = major_doc_df.sort_values(['source_id','doc_type','date'],ascending=False) \
    .drop_duplicates(subset=['source_id','doc_type'],keep='first')

# %%
# Filtering to just the docs I want
doc_list = ['VN','SAR','FCE']
most_recent_docs = most_recent_docs[most_recent_docs.doc_type.isin(doc_list)]

# %%
pd.pivot_table(most_recent_docs, index="source_id",columns=["doc_type"],values='date')\
    .reset_index().to_csv('major-source-recent-docs.csv',index=False)

# %%
major_doc_df.doc_type.value_counts()
# Out:
# TEST      1737
# SAR       1247
# FCE        944
# VN         676
# RVN        500
# ACO         59
# ENFN        44
# TEST2       33
# TEST1       30
# test        22
# STIP         9
# RVN2         4
# RVN1         4
# SEM          2
# TEST01       2
# TEST02       2
# AFO          1
# CJ1          1
# CJ2          1
# RVN3         1
# AQD          1
# Name: doc_type, dtype: int64

# %%
fce_count = pd.crosstab(major_doc_df.source_id, major_doc_df.doc_type)[['FCE']].reset_index()
major_sources = major_sources.merge(fce_count, how="outer",right_on="source_id",left_on="srn")

# %%
vn_count = pd.crosstab(major_doc_df.source_id, major_doc_df.doc_type)[['VN']].reset_index()
major_sources = major_sources.merge(vn_count, how="outer",right_on="source_id",left_on="srn")

# %%
sar_count = pd.crosstab(major_doc_df.source_id, major_doc_df.doc_type)[['SAR']].reset_index()
major_sources = major_sources.merge(sar_count, how="outer",right_on="source_id",left_on="srn")

# %%
major_sources
# Out:
#                         company    srn                address           city  \
# 0           MENASHA CORPORATION  A0023    320 N FARMER STREET         OTSEGO
# 1            MEAD PAPER COMPANY  A0884   7100 COUNTY ROAD 426       ESCANABA
# 2    GENERAL MOTORS CORPORATION  A1641    920 TOWNSEND STREET        LANSING
# 3                   KALSEC, INC  A1991     3713 W MAIN STREET      KALAMAZOO
# 4       E I DUPONT DE NEMOURS &  A3569  400 GROESBECK HIGHWAY  MOUNT CLEMENS
# ..                          ...    ...                    ...            ...
# 280    KAWASAKI MOTORS CORP USA  P0677    5080 36TH STREET SE   GRAND RAPIDS
# 281   TOEFCO ENGINEERED COATING  P0708  1919 INDUSTRIAL DRIVE          NILES
# 282                TRINSEO, LLC  P1025          433W BUILDING        MIDLAND
# 283    DDP SPECIALTY ELECTRONIC  P1027    3400 S SAGINAW ROAD        MIDLAND
# 284    DDP SPECIALTY ELECTRONIC  P1027           954 BUILDING        MIDLAND
#
#     zip_code     county  pti_no.   approved            notes  flag  \
# 0      49078    ALLEGAN  152-96B 2001-04-12  Rolled into ROP     0
# 1      49829      DELTA  800-88A 1998-04-23  Rolled into ROP     0
# 2      48933     INGHAM   69-84A 2000-12-19  Rolled into ROP     0
# 3      49006  KALAMAZOO  104-95A 1997-01-16  Rolled into ROP     0
# 4      48043     MACOMB  646-85A 1997-01-22  Rolled into ROP     0
# ..       ...        ...      ...        ...              ...   ...
# 280    49512       KENT   230-15 2016-03-10  Rolled into ROP     0
# 281    49120    BERRIEN    86-16 2016-07-22  Rolled into ROP     0
# 282    48667    MIDLAND    33-16 2016-04-14  Rolled into ROP     0
# 283    48667    MIDLAND   167-19 2020-01-27  Rolled into ROP     0
# 284    48640    MIDLAND   159-19 2020-03-23  Rolled into ROP     0
#
#                                        full_address  oldest_permit_age  \
# 0             320 N FARMER STREET, OTSEGO, MI 49078              21.05
# 1          7100 COUNTY ROAD 426, ESCANABA, MI 49829              24.02
# 2            920 TOWNSEND STREET, LANSING, MI 48933              21.36
# 3           3713 W MAIN STREET, KALAMAZOO, MI 49005              25.28
# 4    400 GROESBECK HIGHWAY, MOUNT CLEMENS, MI 48043              25.27
# ..                                              ...                ...
# 280     5080 36TH STREET SE, GRAND RAPIDS, MI 49152               6.14
# 281          1919 INDUSTRIAL DRIVE, NILES, MI 49120               5.77
# 282                433W BUILDING, MIDLAND, MI 48667               6.04
# 283          3400 S SAGINAW ROAD, MIDLAND, MI 48667               2.26
# 284                 954 BUILDING, MIDLAND, MI 48674               2.10
#
#      oldest_permit_age_converted source_id_x  FCE source_id_y   VN source_id  \
# 0                           9.00       A0023  2.0       A0023  1.0     A0023
# 1                           9.00       A0884  3.0       A0884  4.0     A0884
# 2                           9.00       A1641  4.0       A1641  0.0     A1641
# 3                           9.00       A1991  3.0       A1991  1.0     A1991
# 4                           9.00       A3569  4.0       A3569  2.0     A3569
# ..                           ...         ...  ...         ...  ...       ...
# 280                         6.14       P0677  3.0       P0677  4.0     P0677
# 281                         5.77       P0708  2.0       P0708  1.0     P0708
# 282                         6.04         NaN  NaN         NaN  NaN       NaN
# 283                         2.26       P1027  0.0       P1027  2.0     P1027
# 284                         2.10       P1027  0.0       P1027  2.0     P1027
#
#      SAR
# 0    4.0
# 1    3.0
# 2    5.0
# 3    3.0
# 4    4.0
# ..   ...
# 280  3.0
# 281  2.0
# 282  NaN
# 283  4.0
# 284  4.0
#
# [285 rows x 19 columns]

# %%
# No documents for 5 companies. HMMM
major_sources.query('FCE.isnull()')
# Out:
#           company    srn        address     city zip_code   county pti_no.  \
# 282  TRINSEO, LLC  P1025  433W BUILDING  MIDLAND    48667  MIDLAND   33-16
#
#       approved            notes  flag                      full_address  \
# 282 2016-04-14  Rolled into ROP     0  433W BUILDING, MIDLAND, MI 48667
#
#      oldest_permit_age  oldest_permit_age_converted source_id_x  FCE  \
# 282               6.04                         6.04         NaN  NaN
#
#     source_id_y  VN source_id  SAR
# 282         NaN NaN       NaN  NaN

# %%
zip_count = major_sources.zip_code.value_counts().to_frame().reset_index().rename({'index':'zip_code','zip_code':'major_sources_in_zip'},axis=1)

# %%
zip_count
# Out:
#     zip_code  major_sources_in_zip
# 0      49601                     7
# 1      48640                     6
# 2      49646                     6
# 3      49464                     6
# 4      49423                     5
# ..       ...                   ...
# 182    48124                     1
# 183    48006                     1
# 184    48207                     1
# 185    48441                     1
# 186    49730                     1
#
# [187 rows x 2 columns]

# %%
major_sources = major_sources.merge(zip_count,how='outer',left_on='zip_code',right_on='zip_code')

# %%
major_sources
# Out:
#                            company    srn                 address  \
# 0              MENASHA CORPORATION  A0023     320 N FARMER STREET
# 1               MEAD PAPER COMPANY  A0884    7100 COUNTY ROAD 426
# 2                DELTA SOLID WASTE  N6035  5701 19TH AVENUE NORTH
# 3       GENERAL MOTORS CORPORATION  A1641     920 TOWNSEND STREET
# 4                      KALSEC, INC  A1991      3713 W MAIN STREET
# ..                             ...    ...                     ...
# 280               HARBOR FOAM, INC  N7754  2950 PRAIRIE STREET SW
# 281  HYUNDAI-KIA AMERICA TECHNICAL  N7886        6800 GEDDES ROAD
# 282             VECTOR PIPELINE LP  N8151         W NE SEC 8, T4S
# 283      PLASAN NORTH AMERICA, INC  P0374    3195 WILSON DRIVE NW
# 284         WOLVERINE POWER SUPPLY  P0582       7432 HIGHWAY M-32
#
#                   city zip_code     county  pti_no.   approved  \
# 0               OTSEGO    49078    ALLEGAN  152-96B 2001-04-12
# 1             ESCANABA    49829      DELTA  800-88A 1998-04-23
# 2             ESCANABA    49829      DELTA    30-03 2003-04-17
# 3              LANSING    48933     INGHAM   69-84A 2000-12-19
# 4            KALAMAZOO    49006  KALAMAZOO  104-95A 1997-01-16
# ..                 ...      ...        ...      ...        ...
# 280         GRANDVILLE    49418       KENT   35-07B 2012-07-30
# 281  SUPERIOR TOWNSHIP    48198  WASHTENAW  285-08C 2013-02-06
# 282    ATHENS TOWNSHIP    49011    CALHOUN   288-08 2008-12-10
# 283             WALKER    49534       KENT    35-16 2016-05-10
# 284    ELMIRA TOWNSHIP    49730     OTSEGO   206-14 2015-05-15
#
#                notes  flag                                   full_address  \
# 0    Rolled into ROP     0          320 N FARMER STREET, OTSEGO, MI 49078
# 1    Rolled into ROP     0       7100 COUNTY ROAD 426, ESCANABA, MI 49829
# 2    Rolled into ROP     0     5701 19TH AVENUE NORTH, ESCANABA, MI 49829
# 3    Rolled into ROP     0         920 TOWNSEND STREET, LANSING, MI 48933
# 4    Rolled into ROP     0        3713 W MAIN STREET, KALAMAZOO, MI 49005
# ..               ...   ...                                            ...
# 280  Rolled into ROP     0   2950 PRAIRIE STREET SW, GRANDVILLE, MI 49418
# 281  Rolled into ROP     0  6800 GEDDES ROAD, SUPERIOR TOWNSHIP, MI 48198
# 282  Rolled into ROP     0     W NE SEC 8, T4S, ATHENS TOWNSHIP, MI 49011
# 283  Rolled into ROP     0         3195 WILSON DRIVE NW, WALKER, MI 49534
# 284  Rolled into ROP     0   7432 HIGHWAY M-32, ELMIRA TOWNSHIP, MI 49730
#
#      oldest_permit_age  oldest_permit_age_converted source_id_x  FCE  \
# 0                21.05                         9.00       A0023  2.0
# 1                24.02                         9.00       A0884  3.0
# 2                19.04                         9.00       N6035  2.0
# 3                21.36                         9.00       A1641  4.0
# 4                25.28                         9.00       A1991  3.0
# ..                 ...                          ...         ...  ...
# 280               9.75                         9.00       N7754  4.0
# 281               9.23                         9.00       N7886  4.0
# 282              13.39                         9.00       N8151  4.0
# 283               5.97                         5.97       P0374  5.0
# 284               6.96                         6.96       P0582  2.0
#
#     source_id_y   VN source_id  SAR  major_sources_in_zip
# 0         A0023  1.0     A0023  4.0                     1
# 1         A0884  4.0     A0884  3.0                     2
# 2         N6035  0.0     N6035  4.0                     2
# 3         A1641  0.0     A1641  5.0                     1
# 4         A1991  1.0     A1991  3.0                     1
# ..          ...  ...       ...  ...                   ...
# 280       N7754  0.0     N7754  4.0                     1
# 281       N7886  0.0     N7886  4.0                     1
# 282       N8151  0.0     N8151  5.0                     1
# 283       P0374  3.0     P0374  5.0                     1
# 284       P0582  0.0     P0582  2.0                     1
#
# [285 rows x 20 columns]

# %% [markdown]
# #### ACS Zip Code Poverty Level for Michigan

# %%
pov_df = pd.read_csv("ACS_MI_Zip_12MonthsPovertyLevelIncome_Pct.csv")

# %%
pov_df.head()
# Out:
#    Unnamed: 0      name    Total  Total, Error  Income Poverty Level  \
# 0           0  Michigan  9741628           0.0                  14.4
# 1           1     48001    11818           0.9                   9.9
# 2           2     48002     3212           1.1                   7.7
# 3           3     48003     6047           3.0                   9.4
# 4           4     48005     5439           1.7                   4.9
#
#    Income Poverty Level, Error
# 0                          0.1
# 1                          2.0
# 2                          3.5
# 3                          3.2
# 4                          2.0

# %% [markdown]
# #### ACS Zip Code Race Demographics for Michigan

# %%
race_df = pd.read_csv("ACS_MI_Zip_RacePct.csv")

# %%
race_df.head()
# Out:
#        name  white_pct  black_pct  am_indian_ak_native_pct  asian_pct  \
# 0  Michigan       78.4       13.8                      0.5        3.1
# 1     48001       97.0        0.1                      0.6        0.6
# 2     48002       98.7        0.0                      0.0        0.0
# 3     48003       98.7        0.0                      0.1        1.0
# 4     48005       97.0        0.8                      0.4        0.2
#
#    hi_pc_islander_pct  other_pct
# 0                 0.0        4.1
# 1                 0.1        1.6
# 2                 0.0        1.3
# 3                 0.0        0.2
# 4                 0.0        1.7

# %% [markdown]
# ## Clean data

# %% [markdown]
# #### Renaming columns

# %%
pov_df.columns = pov_df.columns.str.lower().str.replace(" ","_")

# %%
race_df.columns = race_df.columns.str.lower().str.replace(" ","_")

# %%
major_sources.columns = major_sources.columns.str.lower().str.replace(" ","_")

# %% [markdown]
# ## Creating New Data Frames

# %% [markdown]
# #### Compliance Evaluations -- Zip Code & Source

# %% [markdown]
# ### Merging Data by Source & Demographic Information

# %%
major_sources = major_sources.merge(pov_df, how='left',left_on='zip_code',right_on='name').drop(['unnamed:_0','total,_error','income_poverty_level,_error'],axis=1)

# %%
major_sources = major_sources.merge(race_df, how='left',left_on='zip_code',right_on='name').drop(['source_id','name_x','name_y'],axis=1)

# %%
major_sources = major_sources.drop(['source_id_x','source_id_y'],axis=1)
