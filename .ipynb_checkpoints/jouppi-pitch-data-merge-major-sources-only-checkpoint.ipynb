# %%
import pandas as pd
from plotnine import *

# importing statsmodels (for linear regression in python)
import statsmodels.formula.api as smf

from datetime import date
today = date.today()
today = pd.to_datetime(today)
import numpy as np

# %%
pd.set_option("display.max_columns",None)

# %% [markdown]
# ## Load Data

# %% [markdown]
# #### Michigan air polluter documents & permit data
# These are violation notices, activity reports (inspection), compliance evaluations etc...

# %%
doc_df = pd.read_csv("EGLE-AQD-documents.csv")

# %%
doc_df.head()
# Out:
#    source_id doc_type      date  \
# 0      N8277      ACO  20151217
# 1      N8274      ACO  20151217
# 2  U04060035      SAR  20190716
# 3  U04060035      SAR  20200507
# 4      N7824      FCE  20160525
#
#                                              doc_url
# 0  https://www.egle.state.mi.us/aps/downloads/srn...
# 1  https://www.egle.state.mi.us/aps/downloads/srn...
# 2  https://www.egle.state.mi.us/aps/downloads/srn...
# 3  https://www.egle.state.mi.us/aps/downloads/srn...
# 4  https://www.egle.state.mi.us/aps/downloads/srn...

# %%
pti_df = pd.read_csv("pti-list-clean.csv")
pti_df.head()
# Out:
#                           company    srn  \
# 0  RIVERSIDE ENERGY MICHIGAN, LLC  N8170
# 1    LAMBDA ENERGY RESOURCES, LLC  N7470
# 2    TRENDWELL ENERGY CORPORATION  N7901
# 3       RIVERSIDE ENERGY MICHIGAN  N8070
# 4    LAMBDA ENERGY RESOURCES, LLC  N8074
#
#                                    address                city  zip_code  \
# 0             SECTION 32 - MOUNT MARIA CPF     ALCONA TOWNSHIP   48721.0
# 1        SW SW NW SEC 10, T28N - CALEDONIA  CALEDONIA TOWNSHIP   49735.0
# 2      NW NE SEC 20, T8N, R6E - WOLF CREEK  CALEDONIA TOWNSHIP   48762.0
# 3                   NW NE SEC 20, T8N, R6E  CALEDONIA TOWNSHIP   48619.0
# 4  SW 1/4 SE 1/4 NE 1/4 SEC 8, T28N, R8E -  CALEDONIA TOWNSHIP   49316.0
#
#    pti_no.    approved notes
# 0   329-08  12/17/2008   NaN
# 1   109-05    7/6/2005   NaN
# 2   349-07    1/9/2008   NaN
# 3   188-08   6/30/2008   NaN
# 4  199-08A   1/14/2011   NaN

# %%
# Looking for sources that have "Rolled into ROP" in the notes, because those are Major Sources
major_sources = pti_df.query('notes.str.contains("ROP",na=False)')

# %%
major_sources.approved = pd.to_datetime(major_sources.approved,format="%m/%d/%Y")
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
major_sources.zip_code = major_sources.zip_code.astype("str").str[:5]

# %%
# Filtering out duplicate records for sources, unless that source has a building in a different zip code.
# Saving the oldest permit on file
major_sources = major_sources.sort_values(['srn','approved']).drop_duplicates(subset=['srn','zip_code'])

# %%
fixed_zips = {
    "49005":"49006",
    "48674":"48640",
    "48686":"48640",
    "48121":"48120",
    "48901":"48910",
    "48795":"48759",
    "48824":"48910",
    "48090":"48092",
    "48859":"48858",
    "49937":"49337",
    "49041":"49048",
    "49152":"49512"
    
}

# %%
major_sources = major_sources.replace({"zip_code": fixed_zips})

# %%
# List of major sources
major_srn = major_sources.srn.to_list()

# %%
# Filter doc df to look at only facilities that are major polluters
major_doc_df = doc_df[doc_df.source_id.isin(major_srn)]
major_doc_df
# Out:
#       source_id doc_type      date  \
# 96        B6636      FCE  20200928
# 97        B6636      RVN  20191003
# 98        B6636      RVN  20200831
# 99        B6636      SAR  20200130
# 100       B6636     TEST  20130924
# ...         ...      ...       ...
# 18582     A0023     TEST  20220325
# 18583     B2796     TEST  20220317
# 18584     N2901      FCE  20220113
# 18585     N2901      SAR  20220113
# 18586     N2901     TEST  20220310
#
#                                                  doc_url
# 96     https://www.egle.state.mi.us/aps/downloads/srn...
# 97     https://www.egle.state.mi.us/aps/downloads/srn...
# 98     https://www.egle.state.mi.us/aps/downloads/srn...
# 99     https://www.egle.state.mi.us/aps/downloads/srn...
# 100    https://www.egle.state.mi.us/aps/downloads/srn...
# ...                                                  ...
# 18582  https://www.egle.state.mi.us/aps/downloads/srn...
# 18583  https://www.egle.state.mi.us/aps/downloads/srn...
# 18584  https://www.egle.state.mi.us/aps/downloads/srn...
# 18585  https://www.egle.state.mi.us/aps/downloads/srn...
# 18586  https://www.egle.state.mi.us/aps/downloads/srn...
#
# [5374 rows x 4 columns]

# %%
major_sources['oldest_permit_age'] = today - major_sources.approved
major_sources['oldest_permit_age'] = (major_sources.oldest_permit_age/np.timedelta64(1, 'Y')).round(2)

# %%
major_sources
# Out:
#                                  company    srn  \
# 69                   MENASHA CORPORATION  A0023
# 734                   MEAD PAPER COMPANY  A0884
# 1176          GENERAL MOTORS CORPORATION  A1641
# 1430                         KALSEC, INC  A1991
# 2158     E I DUPONT DE NEMOURS & COMPANY  A3569
# ...                                  ...    ...
# 1801            KAWASAKI MOTORS CORP USA  P0677
# 310    TOEFCO ENGINEERED COATING SYSTEMS  P0708
# 2729                        TRINSEO, LLC  P1025
# 2730  DDP SPECIALTY ELECTRONIC MATERIALS  P1027
# 2731  DDP SPECIALTY ELECTRONIC MATERIALS  P1027
#
#                                 address           city zip_code  pti_no.  \
# 69     320 N FARMER STREET - PAPERBOARD         OTSEGO    49078  152-96B
# 734                7100 COUNTY ROAD 426       ESCANABA    49829  800-88A
# 1176  920 TOWNSEND STREET - BOC LANSING        LANSING    48933   69-84A
# 1430                 3713 W MAIN STREET      KALAMAZOO    49006  104-95A
# 2158      400 GROESBECK HIGHWAY - MOUNT  MOUNT CLEMENS    48043  646-85A
# ...                                 ...            ...      ...      ...
# 1801                5080 36TH STREET SE   GRAND RAPIDS    49512   230-15
# 310               1919 INDUSTRIAL DRIVE          NILES    49120    86-16
# 2729                      433W BUILDING        MIDLAND    48667    33-16
# 2730      3400 S SAGINAW ROAD - UNIT 96        MIDLAND    48667   167-19
# 2731                       954 BUILDING        MIDLAND    48640   159-19
#
#        approved            notes  oldest_permit_age
# 69   2001-04-12  Rolled into ROP              21.05
# 734  1998-04-23  Rolled into ROP              24.02
# 1176 2000-12-19  Rolled into ROP              21.36
# 1430 1997-01-16  Rolled into ROP              25.28
# 2158 1997-01-22  Rolled into ROP              25.27
# ...         ...              ...                ...
# 1801 2016-03-10  Rolled into ROP               6.14
# 310  2016-07-22  Rolled into ROP               5.77
# 2729 2016-04-14  Rolled into ROP               6.04
# 2730 2020-01-27  Rolled into ROP               2.25
# 2731 2020-03-23  Rolled into ROP               2.10
#
# [297 rows x 9 columns]

# %%
# I only have 9 years worth of data so if a permit is longer than 9 years 
# we are going to just say 9 to keep the rate consistent with the data
def years_convert(years):
    if years > 9:
        return 9.0
    else: 
        return years

# %%
major_sources['oldest_permit_age_converted'] = major_sources.oldest_permit_age.apply(years_convert)

# %%
major_sources
# Out:
#                                  company    srn  \
# 69                   MENASHA CORPORATION  A0023
# 734                   MEAD PAPER COMPANY  A0884
# 1176          GENERAL MOTORS CORPORATION  A1641
# 1430                         KALSEC, INC  A1991
# 2158     E I DUPONT DE NEMOURS & COMPANY  A3569
# ...                                  ...    ...
# 1801            KAWASAKI MOTORS CORP USA  P0677
# 310    TOEFCO ENGINEERED COATING SYSTEMS  P0708
# 2729                        TRINSEO, LLC  P1025
# 2730  DDP SPECIALTY ELECTRONIC MATERIALS  P1027
# 2731  DDP SPECIALTY ELECTRONIC MATERIALS  P1027
#
#                                 address           city zip_code  pti_no.  \
# 69     320 N FARMER STREET - PAPERBOARD         OTSEGO    49078  152-96B
# 734                7100 COUNTY ROAD 426       ESCANABA    49829  800-88A
# 1176  920 TOWNSEND STREET - BOC LANSING        LANSING    48933   69-84A
# 1430                 3713 W MAIN STREET      KALAMAZOO    49006  104-95A
# 2158      400 GROESBECK HIGHWAY - MOUNT  MOUNT CLEMENS    48043  646-85A
# ...                                 ...            ...      ...      ...
# 1801                5080 36TH STREET SE   GRAND RAPIDS    49512   230-15
# 310               1919 INDUSTRIAL DRIVE          NILES    49120    86-16
# 2729                      433W BUILDING        MIDLAND    48667    33-16
# 2730      3400 S SAGINAW ROAD - UNIT 96        MIDLAND    48667   167-19
# 2731                       954 BUILDING        MIDLAND    48640   159-19
#
#        approved            notes  oldest_permit_age  \
# 69   2001-04-12  Rolled into ROP              21.05
# 734  1998-04-23  Rolled into ROP              24.02
# 1176 2000-12-19  Rolled into ROP              21.36
# 1430 1997-01-16  Rolled into ROP              25.28
# 2158 1997-01-22  Rolled into ROP              25.27
# ...         ...              ...                ...
# 1801 2016-03-10  Rolled into ROP               6.14
# 310  2016-07-22  Rolled into ROP               5.77
# 2729 2016-04-14  Rolled into ROP               6.04
# 2730 2020-01-27  Rolled into ROP               2.25
# 2731 2020-03-23  Rolled into ROP               2.10
#
#       oldest_permit_age_converted
# 69                           9.00
# 734                          9.00
# 1176                         9.00
# 1430                         9.00
# 2158                         9.00
# ...                           ...
# 1801                         6.14
# 310                          5.77
# 2729                         6.04
# 2730                         2.25
# 2731                         2.10
#
# [297 rows x 10 columns]

# %%
major_doc_df.doc_type = major_doc_df.doc_type.str.replace("FCE1","FCE").str.replace("FCE2","FCE")
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
major_sources
# Out:
#                                  company    srn  \
# 69                   MENASHA CORPORATION  A0023
# 734                   MEAD PAPER COMPANY  A0884
# 1176          GENERAL MOTORS CORPORATION  A1641
# 1430                         KALSEC, INC  A1991
# 2158     E I DUPONT DE NEMOURS & COMPANY  A3569
# ...                                  ...    ...
# 1801            KAWASAKI MOTORS CORP USA  P0677
# 310    TOEFCO ENGINEERED COATING SYSTEMS  P0708
# 2729                        TRINSEO, LLC  P1025
# 2730  DDP SPECIALTY ELECTRONIC MATERIALS  P1027
# 2731  DDP SPECIALTY ELECTRONIC MATERIALS  P1027
#
#                                 address           city zip_code  pti_no.  \
# 69     320 N FARMER STREET - PAPERBOARD         OTSEGO    49078  152-96B
# 734                7100 COUNTY ROAD 426       ESCANABA    49829  800-88A
# 1176  920 TOWNSEND STREET - BOC LANSING        LANSING    48933   69-84A
# 1430                 3713 W MAIN STREET      KALAMAZOO    49006  104-95A
# 2158      400 GROESBECK HIGHWAY - MOUNT  MOUNT CLEMENS    48043  646-85A
# ...                                 ...            ...      ...      ...
# 1801                5080 36TH STREET SE   GRAND RAPIDS    49512   230-15
# 310               1919 INDUSTRIAL DRIVE          NILES    49120    86-16
# 2729                      433W BUILDING        MIDLAND    48667    33-16
# 2730      3400 S SAGINAW ROAD - UNIT 96        MIDLAND    48667   167-19
# 2731                       954 BUILDING        MIDLAND    48640   159-19
#
#        approved            notes  oldest_permit_age  \
# 69   2001-04-12  Rolled into ROP              21.05
# 734  1998-04-23  Rolled into ROP              24.02
# 1176 2000-12-19  Rolled into ROP              21.36
# 1430 1997-01-16  Rolled into ROP              25.28
# 2158 1997-01-22  Rolled into ROP              25.27
# ...         ...              ...                ...
# 1801 2016-03-10  Rolled into ROP               6.14
# 310  2016-07-22  Rolled into ROP               5.77
# 2729 2016-04-14  Rolled into ROP               6.04
# 2730 2020-01-27  Rolled into ROP               2.25
# 2731 2020-03-23  Rolled into ROP               2.10
#
#       oldest_permit_age_converted
# 69                           9.00
# 734                          9.00
# 1176                         9.00
# 1430                         9.00
# 2158                         9.00
# ...                           ...
# 1801                         6.14
# 310                          5.77
# 2729                         6.04
# 2730                         2.25
# 2731                         2.10
#
# [297 rows x 10 columns]

# %%
fce_count = pd.crosstab(major_doc_df.source_id, major_doc_df.doc_type)[['FCE']].reset_index()
major_sources = major_sources.merge(fce_count, how="outer",right_on="source_id",left_on="srn")

# %%
# No documents for 5 companies. HMMM
major_sources.query('FCE.isnull()')
# Out:
#                           company    srn                      address  \
# 17     DOTT MANUFACTURING COMPANY  A6466           3768 N MAIN STREET
# 73         DETROIT EDISON COMPANY  B2813             301 GRATIOT BLVD
# 149          SMELTZER ENTERPRISES  K0291         10600 GRATIOT AVENUE
# 264  MICHIGAN SOUTH CENTRAL POWER  N6885  SE CORNER OF E STATE STREET
# 294                  TRINSEO, LLC  P1025                433W BUILDING
#
#             city zip_code  pti_no.   approved            notes  \
# 17   DECKERVILLE    48427  390-92B 1999-12-01  Rolled into ROP
# 73    MARYSVILLE    48040  523-88A 2000-08-09  Rolled into ROP
# 149      DETROIT    48213    62-97 1997-12-01  Rolled into ROP
# 264    COLDWATER    49036   320-00 2000-12-01  Rolled into ROP
# 294      MIDLAND    48667    33-16 2016-04-14  Rolled into ROP
#
#      oldest_permit_age  oldest_permit_age_converted source_id  FCE
# 17               22.41                         9.00       NaN  NaN
# 73               21.72                         9.00       NaN  NaN
# 149              24.41                         9.00       NaN  NaN
# 264              21.41                         9.00       NaN  NaN
# 294               6.04                         6.04       NaN  NaN

# %%
zip_count = major_sources.zip_code.value_counts().to_frame().reset_index().rename({'index':'zip_code','zip_code':'major_sources_in_zip'},axis=1)

# %%
zip_count
# Out:
#     zip_code  major_sources_in_zip
# 0      49601                     7
# 1      49464                     6
# 2      48640                     6
# 3      49423                     6
# 4      49646                     6
# ..       ...                   ...
# 187    49659                     1
# 188    48381                     1
# 189    49348                     1
# 190    49733                     1
# 191    49730                     1
#
# [192 rows x 2 columns]

# %%
major_sources.merge(zip_count,how='outer',left_on='zip_code',right_on='zip_code')
# Out:
#                            company    srn                             address  \
# 0              MENASHA CORPORATION  A0023    320 N FARMER STREET - PAPERBOARD
# 1               MEAD PAPER COMPANY  A0884                7100 COUNTY ROAD 426
# 2     DELTA SOLID WASTE MANAGEMENT  N6035              5701 19TH AVENUE NORTH
# 3       GENERAL MOTORS CORPORATION  A1641   920 TOWNSEND STREET - BOC LANSING
# 4                      KALSEC, INC  A1991                  3713 W MAIN STREET
# ..                             ...    ...                                 ...
# 292               HARBOR FOAM, INC  N7754  2950 PRAIRIE STREET SW - SUITE 300
# 293  HYUNDAI-KIA AMERICA TECHNICAL  N7886                    6800 GEDDES ROAD
# 294             VECTOR PIPELINE LP  N8151                     W NE SEC 8, T4S
# 295      PLASAN NORTH AMERICA, INC  P0374                3195 WILSON DRIVE NW
# 296         WOLVERINE POWER SUPPLY  P0582    7432 HIGHWAY M-32 - ALPINE POWER
#
#                   city zip_code  pti_no.   approved            notes  \
# 0               OTSEGO    49078  152-96B 2001-04-12  Rolled into ROP
# 1             ESCANABA    49829  800-88A 1998-04-23  Rolled into ROP
# 2             ESCANABA    49829    30-03 2003-04-17  Rolled into ROP
# 3              LANSING    48933   69-84A 2000-12-19  Rolled into ROP
# 4            KALAMAZOO    49006  104-95A 1997-01-16  Rolled into ROP
# ..                 ...      ...      ...        ...              ...
# 292         GRANDVILLE    49418   35-07B 2012-07-30  Rolled into ROP
# 293  SUPERIOR TOWNSHIP    48198  285-08C 2013-02-06  Rolled into ROP
# 294    ATHENS TOWNSHIP    49011   288-08 2008-12-10  Rolled into ROP
# 295             WALKER    49534    35-16 2016-05-10  Rolled into ROP
# 296    ELMIRA TOWNSHIP    49730   206-14 2015-05-15  Rolled into ROP
#
#      oldest_permit_age  oldest_permit_age_converted source_id  FCE  \
# 0                21.05                         9.00     A0023  2.0
# 1                24.02                         9.00     A0884  3.0
# 2                19.03                         9.00     N6035  2.0
# 3                21.36                         9.00     A1641  4.0
# 4                25.28                         9.00     A1991  3.0
# ..                 ...                          ...       ...  ...
# 292               9.75                         9.00     N7754  4.0
# 293               9.22                         9.00     N7886  4.0
# 294              13.38                         9.00     N8151  4.0
# 295               5.97                         5.97     P0374  5.0
# 296               6.96                         6.96     P0582  2.0
#
#      major_sources_in_zip
# 0                       1
# 1                       2
# 2                       2
# 3                       1
# 4                       1
# ..                    ...
# 292                     1
# 293                     1
# 294                     1
# 295                     1
# 296                     1
#
# [297 rows x 13 columns]

# %% [markdown]
# #### ACS Zip Code Poverty Level for Michigan

# %%
pov_df = pd.read_csv("ACS_MI_Zip_12MonthsPovertyLevelIncome_Pct.csv")

# %%
pov_df.head()
# Out:
#    Unnamed: 0      name    Total  Total, Error  Income Poverty Level  \
# 0           0  Michigan  9741628           0.0                  14.4
# 1           1     48001    11818           0.9                   9.9
# 2           2     48002     3212           1.1                   7.7
# 3           3     48003     6047           3.0                   9.4
# 4           4     48005     5439           1.7                   4.9
#
#    Income Poverty Level, Error
# 0                          0.1
# 1                          2.0
# 2                          3.5
# 3                          3.2
# 4                          2.0

# %% [markdown]
# #### ACS Zip Code Race Demographics for Michigan

# %%
race_df = pd.read_csv("ACS_MI_Zip_RacePct.csv")

# %%
race_df.head()
# Out:
#        name  white_pct  black_pct  am_indian_ak_native_pct  asian_pct  \
# 0  Michigan       78.4       13.8                      0.5        3.1
# 1     48001       97.0        0.1                      0.6        0.6
# 2     48002       98.7        0.0                      0.0        0.0
# 3     48003       98.7        0.0                      0.1        1.0
# 4     48005       97.0        0.8                      0.4        0.2
#
#    hi_pc_islander_pct  other_pct
# 0                 0.0        4.1
# 1                 0.1        1.6
# 2                 0.0        1.3
# 3                 0.0        0.2
# 4                 0.0        1.7

# %% [markdown]
# ## Clean data

# %% [markdown]
# #### Renaming columns

# %%
pov_df.columns = pov_df.columns.str.lower().str.replace(" ","_")

# %%
race_df.columns = race_df.columns.str.lower().str.replace(" ","_")

# %% [markdown]
# #### Change zip codes to str

# %% [markdown]
# ## Creating New Data Frames

# %% [markdown]
# #### Compliance Evaluations -- Zip Code & Source

# %% [markdown]
# ### Merging Data by Source & Demographic Information

# %%
major_sources = major_sources.merge(pov_df, how='left',left_on='zip_code',right_on='name').drop(['unnamed:_0','total,_error','income_poverty_level,_error'],axis=1)

# %%
major_sources = major_sources.merge(race_df, how='left',left_on='zip_code',right_on='name').drop(['source_id','name_x','name_y'],axis=1)

# %%
major_sources
# Out:
#                                 company    srn  \
# 0                   MENASHA CORPORATION  A0023
# 1                    MEAD PAPER COMPANY  A0884
# 2            GENERAL MOTORS CORPORATION  A1641
# 3                           KALSEC, INC  A1991
# 4       E I DUPONT DE NEMOURS & COMPANY  A3569
# ..                                  ...    ...
# 292            KAWASAKI MOTORS CORP USA  P0677
# 293   TOEFCO ENGINEERED COATING SYSTEMS  P0708
# 294                        TRINSEO, LLC  P1025
# 295  DDP SPECIALTY ELECTRONIC MATERIALS  P1027
# 296  DDP SPECIALTY ELECTRONIC MATERIALS  P1027
#
#                                address           city zip_code  pti_no.  \
# 0     320 N FARMER STREET - PAPERBOARD         OTSEGO    49078  152-96B
# 1                 7100 COUNTY ROAD 426       ESCANABA    49829  800-88A
# 2    920 TOWNSEND STREET - BOC LANSING        LANSING    48933   69-84A
# 3                   3713 W MAIN STREET      KALAMAZOO    49006  104-95A
# 4        400 GROESBECK HIGHWAY - MOUNT  MOUNT CLEMENS    48043  646-85A
# ..                                 ...            ...      ...      ...
# 292                5080 36TH STREET SE   GRAND RAPIDS    49512   230-15
# 293              1919 INDUSTRIAL DRIVE          NILES    49120    86-16
# 294                      433W BUILDING        MIDLAND    48667    33-16
# 295      3400 S SAGINAW ROAD - UNIT 96        MIDLAND    48667   167-19
# 296                       954 BUILDING        MIDLAND    48640   159-19
#
#       approved            notes  oldest_permit_age  \
# 0   2001-04-12  Rolled into ROP              21.05
# 1   1998-04-23  Rolled into ROP              24.02
# 2   2000-12-19  Rolled into ROP              21.36
# 3   1997-01-16  Rolled into ROP              25.28
# 4   1997-01-22  Rolled into ROP              25.27
# ..         ...              ...                ...
# 292 2016-03-10  Rolled into ROP               6.14
# 293 2016-07-22  Rolled into ROP               5.77
# 294 2016-04-14  Rolled into ROP               6.04
# 295 2020-01-27  Rolled into ROP               2.25
# 296 2020-03-23  Rolled into ROP               2.10
#
#      oldest_permit_age_converted  FCE  total  income_poverty_level  white_pct  \
# 0                           9.00  2.0   9316                  10.7       94.5
# 1                           9.00  3.0  16443                  16.3       93.1
# 2                           9.00  4.0   2636                  39.9       48.1
# 3                           9.00  3.0  24556                  36.4       74.0
# 4                           9.00  4.0  14857                  20.1       70.3
# ..                           ...  ...    ...                   ...        ...
# 292                         6.14  3.0  17528                   8.7       62.6
# 293                         5.77  2.0  35993                  14.8       88.5
# 294                         6.04  NaN      0                   NaN        NaN
# 295                         2.25  0.0      0                   NaN        NaN
# 296                         2.10  0.0  31553                  11.9       93.4
#
#      black_pct  am_indian_ak_native_pct  asian_pct  hi_pc_islander_pct  \
# 0          0.7                      0.1        0.6                 0.0
# 1          0.6                      2.1        0.6                 0.0
# 2         34.2                      1.2        3.3                 0.5
# 3         14.4                      0.2        4.0                 0.0
# 4         24.6                      0.4        0.1                 0.0
# ..         ...                      ...        ...                 ...
# 292       28.4                      0.2        6.7                 0.2
# 293        6.6                      0.6        0.6                 0.0
# 294        NaN                      NaN        NaN                 NaN
# 295        NaN                      NaN        NaN                 NaN
# 296        1.9                      0.2        1.9                 0.1
#
#      other_pct
# 0          4.1
# 1          3.6
# 2         12.6
# 3          7.5
# 4          4.6
# ..         ...
# 292        1.9
# 293        3.7
# 294        NaN
# 295        NaN
# 296        2.5
#
# [297 rows x 19 columns]

# %%
major_sources.query('total.isnull()')
# Out:
# Empty DataFrame
# Columns: [company, srn, address, city, zip_code, pti_no., approved, notes, oldest_permit_age, oldest_permit_age_converted, FCE, total, income_poverty_level, white_pct, black_pct, am_indian_ak_native_pct, asian_pct, hi_pc_islander_pct, other_pct]
# Index: []

# %% [markdown]
# ### Getting permit start date and duration

# %%
pti_df.head()
# Out:
#                           company    srn  \
# 0  RIVERSIDE ENERGY MICHIGAN, LLC  N8170
# 1    LAMBDA ENERGY RESOURCES, LLC  N7470
# 2    TRENDWELL ENERGY CORPORATION  N7901
# 3       RIVERSIDE ENERGY MICHIGAN  N8070
# 4    LAMBDA ENERGY RESOURCES, LLC  N8074
#
#                                    address                city  zip_code  \
# 0             SECTION 32 - MOUNT MARIA CPF     ALCONA TOWNSHIP   48721.0
# 1        SW SW NW SEC 10, T28N - CALEDONIA  CALEDONIA TOWNSHIP   49735.0
# 2      NW NE SEC 20, T8N, R6E - WOLF CREEK  CALEDONIA TOWNSHIP   48762.0
# 3                   NW NE SEC 20, T8N, R6E  CALEDONIA TOWNSHIP   48619.0
# 4  SW 1/4 SE 1/4 NE 1/4 SEC 8, T28N, R8E -  CALEDONIA TOWNSHIP   49316.0
#
#    pti_no.    approved notes
# 0   329-08  12/17/2008   NaN
# 1   109-05    7/6/2005   NaN
# 2   349-07    1/9/2008   NaN
# 3   188-08   6/30/2008   NaN
# 4  199-08A   1/14/2011   NaN

# %%
from datetime import date
today = date.today()
today = pd.to_datetime(today)
import numpy as np

# %%
# Converting permit approval date to datetime
pti_df.approved = pd.to_datetime(pti_df.approved, format="%m/%d/%Y")

# %%
# Multiple permits per source so let's take the earliest permit date for each source
pti_approved_date = pti_df.groupby("srn").approved.min().to_frame().reset_index()

# %%
# Converting to years
pti_approved_date['years'] = today - pti_approved_date.approved
pti_approved_date.years = pti_approved_date.years/np.timedelta64(1, 'Y')

# %%
# I only have 9 years worth of data so if a permit is longer than 9 years 
# we are going to just say 9 to keep the rate consistent with the data
def years_convert(years):
    if years > 9:
        return 9.0
    else: 
        return years

# %%
pti_approved_date['years_converted'] = pti_approved_date.years.apply(years_convert)

# %%
pti_approved_date
# Out:
#         srn   approved      years  years_converted
# 0     A0023 2001-04-12  20.969630         9.000000
# 1     A0083 2015-01-14   7.211647         7.211647
# 2     A0085 2016-04-27   5.927569         5.927569
# 3     A0098 2004-11-29  17.336427         9.000000
# 4     A0099 2000-08-08  21.645893         9.000000
# ...     ...        ...        ...              ...
# 2991  P1249 2021-12-14   0.295694         0.295694
# 2992  P1251 2022-02-01   0.161537         0.161537
# 2993  P1252 2022-02-01   0.161537         0.161537
# 2994  P1253 2022-02-08   0.142371         0.142371
# 2995  P1257 2022-03-15   0.046544         0.046544
#
# [2996 rows x 4 columns]

# %%
df = df.merge(pti_approved_date,how="left",right_on="srn", left_on="id")

# %%
df['fce_per_year'] = df.fce / df.years_converted

# %%
df.head()
# Out:
#       id                     name_x zip_code       county  \
# 0  A6260  ALGONAC CAST PRODUCTS INC    48001  SAINT CLAIR
# 1  N6769     SUNSATION PRODUCTS INC    48001  SAINT CLAIR
# 2  P1024     ALTA EQUIPMENT COMPANY    48001         KENT
# 3  P1089               CARL SCHEGEL    48001      JACKSON
# 4  P1015        ENBRIDGE ENERGY, LP    48001         IRON
#
#                                   full_address  \
# 0                 9300 STONE ROAD, ALGONAC, MI
# 1                   9635 KRETZ DR, ALGONAC, MI
# 2  8840 BYRON COMMERCE DRIVE, BYRON CENTER, MI
# 3                  4500 MANN ROAD, CONCORD, MI
# 4        SEC 35, T43N, R32W, CRYSTAL FALLS, MI
#
#                            geometry  fce  sar  violations    total  \
# 0  [-82.54572189999999, 42.6299997]  0.0  1.0         0.0  11818.0
# 1         [-82.5700738, 42.6222489]  0.0  2.0         0.0  11818.0
# 2  [-85.6703763, 42.80414830000001]  0.0  0.0         0.0  11818.0
# 3  [-84.68608139999999, 42.1971472]  0.0  0.0         0.0  11818.0
# 4         [-88.3340242, 46.0980066]  0.0  0.0         0.0  11818.0
#
#    income_poverty_level  white_pct  black_pct  am_indian_ak_native_pct  \
# 0                   9.9       97.0        0.1                      0.6
# 1                   9.9       97.0        0.1                      0.6
# 2                   9.9       97.0        0.1                      0.6
# 3                   9.9       97.0        0.1                      0.6
# 4                   9.9       97.0        0.1                      0.6
#
#    asian_pct  hi_pc_islander_pct  other_pct    srn   approved     years  \
# 0        0.6                 0.1        1.6  A6260 2014-01-23  8.186342
# 1        0.6                 0.1        1.6  N6769 2014-09-18  7.534720
# 2        0.6                 0.1        1.6  P1024 2019-05-13  2.885754
# 3        0.6                 0.1        1.6  P1089 2019-10-29  2.423048
# 4        0.6                 0.1        1.6  P1015 2021-05-25  0.851489
#
#    years_converted  fce_per_year
# 0         8.186342           0.0
# 1         7.534720           0.0
# 2         2.885754           0.0
# 3         2.423048           0.0
# 4         0.851489           0.0

# %%
df.to_csv("documents-by-source-demographics.csv",index=False)

# %% [markdown]
# #### Merge all zip code level data

# %%
zip_df = source_df.zip_code.value_counts().to_frame().reset_index().rename({'index':'zip_code','zip_code':'sources'},axis=1)

# %%
# Merge FCE
zip_df = zip_df.merge(zip_fce,how="outer",left_on="zip_code",right_on="zip_code")

# %%
# Merge SAR
zip_df = zip_df.merge(zip_sar,how="outer",left_on="zip_code",right_on="zip_code")

# %%
# Merge Violations
zip_df = zip_df.merge(zip_vn,how="outer",left_on="zip_code",right_on="zip_code")

# %%
# Merge poverty data
zip_df = zip_df.merge(pov_df,how='left',left_on='zip_code',right_on="name")

# %%
# Merge race data
zip_df = zip_df.merge(race_df, how="left",left_on="zip_code",right_on="name")

# %%
zip_df = zip_df.drop(['unnamed:_0','name_x','total,_error','name_y','income_poverty_level,_error'],axis=1)

# %%
zip_df.to_csv("violations-fce-sar-by-zip.csv",index=False)
