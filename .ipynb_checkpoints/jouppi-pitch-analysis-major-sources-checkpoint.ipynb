# %%
import pandas as pd
from plotnine import *
pd.set_option('display.max_columns', 500)
import numpy as np

# %% [markdown]
# ### I'm interested in evaluations (FCE) -- how much is the number of evaluations a source has related to poverty or race?

# %%
df = pd.read_csv("major-sources-demographic.csv")

# %%
df.head()
# Out:
#                         company    srn                            address  \
# 0           MENASHA CORPORATION  A0023   320 N FARMER STREET - PAPERBOARD
# 1            MEAD PAPER COMPANY  A0884               7100 COUNTY ROAD 426
# 2  DELTA SOLID WASTE MANAGEMENT  N6035             5701 19TH AVENUE NORTH
# 3    GENERAL MOTORS CORPORATION  A1641  920 TOWNSEND STREET - BOC LANSING
# 4                   KALSEC, INC  A1991                 3713 W MAIN STREET
#
#         city  zip_code  pti_no.    approved            notes  \
# 0     OTSEGO     49078  152-96B  2001-04-12  Rolled into ROP
# 1   ESCANABA     49829  800-88A  1998-04-23  Rolled into ROP
# 2   ESCANABA     49829    30-03  2003-04-17  Rolled into ROP
# 3    LANSING     48933   69-84A  2000-12-19  Rolled into ROP
# 4  KALAMAZOO     49006  104-95A  1997-01-16  Rolled into ROP
#
#    oldest_permit_age  oldest_permit_age_converted  FCE  total  \
# 0              21.05                          9.0  2.0   9316
# 1              24.02                          9.0  3.0  16443
# 2              19.03                          9.0  2.0  16443
# 3              21.36                          9.0  4.0   2636
# 4              25.28                          9.0  3.0  24556
#
#    income_poverty_level  white_pct  black_pct  am_indian_ak_native_pct  \
# 0                  10.7       94.5        0.7                      0.1
# 1                  16.3       93.1        0.6                      2.1
# 2                  16.3       93.1        0.6                      2.1
# 3                  39.9       48.1       34.2                      1.2
# 4                  36.4       74.0       14.4                      0.2
#
#    asian_pct  hi_pc_islander_pct  other_pct  major_sources_in_zip
# 0        0.6                 0.0        4.1                     1
# 1        0.6                 0.0        3.6                     2
# 2        0.6                 0.0        3.6                     2
# 3        3.3                 0.5       12.6                     1
# 4        4.0                 0.0        7.5                     1

# %%
df['fce_per_year'] = df.oldest_permit_age_converted / df.FCE

# %%
df['fce_goal'] = df.oldest_permit_age_converted / 2

# %%
df.fce_goal = df.fce_goal.apply(np.floor)

# %%
df['fce_difference'] = df.FCE - df.fce_goal

# %%
df.sort_values('oldest_permit_age_converted', ascending=True)
# Out:
#                                 company    srn  \
# 105         PANHANDLE EASTERN PIPE LINE  N5572
# 230           ENERGY DEVELOPMENTS BYRON  N1324
# 21   DDP SPECIALTY ELECTRONIC MATERIALS  P1027
# 15   DDP SPECIALTY ELECTRONIC MATERIALS  P1027
# 214           MOLDED PLASTIC INDUSTRIES  N0034
# ..                                  ...    ...
# 101              DETROIT EDISON COMPANY  B2810
# 100          CARMEUSE LIME & STONE, INC  B2169
# 99          DAIMLERCHRYSLER CORPORATION  B3350
# 106           HOWARD PLATING INDUSTRIES  B2363
# 148                  QUANEX CORPORATION  B4306
#
#                                  address             city  zip_code  pti_no.  \
# 105               3990 CROOKED LAKE ROAD           HOWELL     48843    72-20
# 230                10300 S KENT DRIVE SW     BYRON CENTER     49315  212-08B
# 21                          954 BUILDING          MIDLAND     48640   159-19
# 15         3400 S SAGINAW ROAD - UNIT 96          MIDLAND     48667   167-19
# 214                     2382 JARCO DRIVE             HOLT     48842   106-18
# ..                                   ...              ...       ...      ...
# 101  1 BELANGER PARK DRIVE - RIVER ROUGE      RIVER ROUGE     48218   269-99
# 100       25 MARION AVENUE - RIVER ROUGE      RIVER ROUGE     48218  330-07D
# 99   2000 VAN HORN ROAD - TRENTON ENGINE          TRENTON     48183    95-07
# 106                 32565 DEQUINDRE ROAD  MADISON HEIGHTS     48071   460-97
# 148        3100 BROOKLYN ROAD - MACSTEEL          JACKSON     49203  535-96B
#
#        approved            notes  oldest_permit_age  \
# 105  2020-09-02  Rolled into ROP               1.65
# 230  2020-05-28  Rolled into ROP               1.92
# 21   2020-03-23  Rolled into ROP               2.10
# 15   2020-01-27  Rolled into ROP               2.25
# 214  2018-11-05  Rolled into ROP               3.48
# ..          ...              ...                ...
# 101  1999-12-02  Rolled into ROP              22.41
# 100  2012-02-17  Rolled into ROP              10.20
# 99   2007-04-19  Rolled into ROP              15.03
# 106  1997-11-18  Rolled into ROP              24.44
# 148  1999-11-24  Rolled into ROP              22.43
#
#      oldest_permit_age_converted  FCE  total  income_poverty_level  white_pct  \
# 105                         1.65  3.0  44707                   5.2       95.9
# 230                         1.92  5.0  23148                   3.3       91.3
# 21                          2.10  0.0  31553                  11.9       93.4
# 15                          2.25  0.0      0                   NaN        NaN
# 214                         3.48  1.0  21877                  11.6       82.8
# ..                           ...  ...    ...                   ...        ...
# 101                         9.00  3.0   7502                  42.2       41.3
# 100                         9.00  3.0   7502                  42.2       41.3
# 99                          9.00  2.0  41758                   7.6       89.8
# 106                         9.00  3.0  29964                  13.6       80.8
# 148                         9.00  5.0  38281                  19.0       79.8
#
#      black_pct  am_indian_ak_native_pct  asian_pct  hi_pc_islander_pct  \
# 105        0.5                      0.2        1.0                 0.2
# 230        1.4                      0.5        3.6                 0.0
# 21         1.9                      0.2        1.9                 0.1
# 15         NaN                      NaN        NaN                 NaN
# 214        7.4                      0.2        4.2                 0.0
# ..         ...                      ...        ...                 ...
# 101       48.9                      0.4        0.0                 0.0
# 100       48.9                      0.4        0.0                 0.0
# 99         5.0                      0.1        2.6                 0.0
# 106        8.5                      0.4        5.8                 0.0
# 148       13.7                      0.2        0.9                 0.1
#
#      other_pct  major_sources_in_zip  fce_per_year  fce_goal  fce_difference
# 105        2.2                     2         0.550       0.0             3.0
# 230        3.2                     2         0.384       0.0             5.0
# 21         2.5                     6           inf       1.0            -1.0
# 15         NaN                     3           inf       1.0            -1.0
# 214        5.3                     1         3.480       1.0             0.0
# ..         ...                   ...           ...       ...             ...
# 101        9.5                     4         3.000       4.0            -1.0
# 100        9.5                     4         3.000       4.0            -1.0
# 99         2.6                     3         4.500       4.0            -2.0
# 106        4.5                     1         3.000       4.0            -1.0
# 148        5.4                     2         1.800       4.0             1.0
#
# [297 rows x 23 columns]

# %%
df.FCE.hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df.major_sources_in_zip.hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df_zip = df.groupby('zip_code').FCE.sum().to_frame().reset_index()

# %%
df.groupby('zip_code').fce_difference.sum().to_frame().reset_index()
# Out:
#      zip_code  fce_difference
# 0       48005            -3.0
# 1       48006            -1.0
# 2       48014             1.0
# 3       48023            -2.0
# 4       48040             2.0
# ..        ...             ...
# 187     49871            -1.0
# 188     49876            -1.0
# 189     49881             0.0
# 190     49946            -1.0
# 191     49971            -3.0
#
# [192 rows x 2 columns]

# %%
df_zip = df.groupby('zip_code').FCE.sum().to_frame().reset_index()

# %%
df.drop_duplicates(subset='zip_code')[['']]
# Out:
#                              company    srn  \
# 0                MENASHA CORPORATION  A0023
# 1                 MEAD PAPER COMPANY  A0884
# 3         GENERAL MOTORS CORPORATION  A1641
# 4                        KALSEC, INC  A1991
# 5    E I DUPONT DE NEMOURS & COMPANY  A3569
# ..                               ...    ...
# 292                 HARBOR FOAM, INC  N7754
# 293    HYUNDAI-KIA AMERICA TECHNICAL  N7886
# 294               VECTOR PIPELINE LP  N8151
# 295        PLASAN NORTH AMERICA, INC  P0374
# 296           WOLVERINE POWER SUPPLY  P0582
#
#                                 address               city  zip_code  pti_no.  \
# 0      320 N FARMER STREET - PAPERBOARD             OTSEGO     49078  152-96B
# 1                  7100 COUNTY ROAD 426           ESCANABA     49829  800-88A
# 3     920 TOWNSEND STREET - BOC LANSING            LANSING     48933   69-84A
# 4                    3713 W MAIN STREET          KALAMAZOO     49006  104-95A
# 5         400 GROESBECK HIGHWAY - MOUNT      MOUNT CLEMENS     48043  646-85A
# ..                                  ...                ...       ...      ...
# 292  2950 PRAIRIE STREET SW - SUITE 300         GRANDVILLE     49418   35-07B
# 293                    6800 GEDDES ROAD  SUPERIOR TOWNSHIP     48198  285-08C
# 294                     W NE SEC 8, T4S    ATHENS TOWNSHIP     49011   288-08
# 295                3195 WILSON DRIVE NW             WALKER     49534    35-16
# 296    7432 HIGHWAY M-32 - ALPINE POWER    ELMIRA TOWNSHIP     49730   206-14
#
#        approved            notes  oldest_permit_age  \
# 0    2001-04-12  Rolled into ROP              21.05
# 1    1998-04-23  Rolled into ROP              24.02
# 3    2000-12-19  Rolled into ROP              21.36
# 4    1997-01-16  Rolled into ROP              25.28
# 5    1997-01-22  Rolled into ROP              25.27
# ..          ...              ...                ...
# 292  2012-07-30  Rolled into ROP               9.75
# 293  2013-02-06  Rolled into ROP               9.22
# 294  2008-12-10  Rolled into ROP              13.38
# 295  2016-05-10  Rolled into ROP               5.97
# 296  2015-05-15  Rolled into ROP               6.96
#
#      oldest_permit_age_converted  FCE  total  income_poverty_level  white_pct  \
# 0                           9.00  2.0   9316                  10.7       94.5
# 1                           9.00  3.0  16443                  16.3       93.1
# 3                           9.00  4.0   2636                  39.9       48.1
# 4                           9.00  3.0  24556                  36.4       74.0
# 5                           9.00  4.0  14857                  20.1       70.3
# ..                           ...  ...    ...                   ...        ...
# 292                         9.00  4.0  28231                   6.0       89.1
# 293                         9.00  4.0  38081                  21.4       54.7
# 294                         9.00  4.0   2269                  10.2       94.7
# 295                         5.97  5.0  21803                   6.2       92.7
# 296                         6.96  2.0   2187                  10.7       97.0
#
#      black_pct  am_indian_ak_native_pct  asian_pct  hi_pc_islander_pct  \
# 0          0.7                      0.1        0.6                 0.0
# 1          0.6                      2.1        0.6                 0.0
# 3         34.2                      1.2        3.3                 0.5
# 4         14.4                      0.2        4.0                 0.0
# 5         24.6                      0.4        0.1                 0.0
# ..         ...                      ...        ...                 ...
# 292        1.2                      0.5        2.9                 0.0
# 293       36.5                      0.9        2.0                 0.1
# 294        2.2                      0.6        0.0                 0.0
# 295        1.7                      0.1        2.4                 0.0
# 296        0.6                      0.2        0.3                 0.0
#
#      other_pct  major_sources_in_zip  fce_per_year  fce_goal  fce_difference
# 0          4.1                     1         4.500       4.0            -2.0
# 1          3.6                     2         3.000       4.0            -1.0
# 3         12.6                     1         2.250       4.0             0.0
# 4          7.5                     1         3.000       4.0            -1.0
# 5          4.6                     1         2.250       4.0             0.0
# ..         ...                   ...           ...       ...             ...
# 292        6.4                     1         2.250       4.0             0.0
# 293        5.8                     1         2.250       4.0             0.0
# 294        2.4                     1         2.250       4.0             0.0
# 295        3.1                     1         1.194       2.0             3.0
# 296        2.0                     1         3.480       3.0            -1.0
#
# [192 rows x 23 columns]

# %%
(
    ggplot(df,
          aes(x='income_poverty_level',y='FCE'))
        + geom_point()
)
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 8 rows containing missing values.
# <ggplot: (333430393)>

# %%
(
    ggplot(df,
          aes(x='black_pct',y='FCE'))
        + geom_point()
)
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 8 rows containing missing values.
# <ggplot: (333493751)>

# %%
(
    ggplot(df,
          aes(x='black_pct',y='fce_per_year'))
        + geom_point()
)
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 8 rows containing missing values.
# <ggplot: (333595308)>

# %%
(
    ggplot(df,
          aes(x='income_poverty_level',y='fce_difference'))
        + geom_point()
)
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 8 rows containing missing values.
# <ggplot: (333810836)>

# %%
(
    ggplot(df,
          aes(x='black_pct',y='fce_difference'))
        + geom_point()
)
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 8 rows containing missing values.
# <ggplot: (333853904)>

# %%
(
    ggplot(df,
          aes(x='black_pct',y='major_sources_in_zip'))
        + geom_point()
)
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 4 rows containing missing values.
# <ggplot: (335417932)>

# %%
(
    ggplot(df,
          aes(x='income_poverty_level',y='major_sources_in_zip'))
        + geom_point()
)
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 4 rows containing missing values.
# <ggplot: (334315123)>

# %%
df.corr().round(2)
# Out:
#                              zip_code  oldest_permit_age  \
# zip_code                         1.00               0.03
# oldest_permit_age                0.03               1.00
# oldest_permit_age_converted     -0.05               0.65
# FCE                              0.16               0.09
# total                           -0.15              -0.14
# income_poverty_level            -0.19               0.14
# white_pct                        0.34               0.02
# black_pct                       -0.33              -0.01
# am_indian_ak_native_pct          0.36               0.02
# asian_pct                       -0.28              -0.09
# hi_pc_islander_pct              -0.06               0.02
# other_pct                       -0.07               0.02
# major_sources_in_zip             0.24               0.03
# fce_per_year                    -0.16               0.19
# fce_goal                        -0.05               0.64
# fce_difference                   0.18              -0.24
#
#                              oldest_permit_age_converted   FCE  total  \
# zip_code                                           -0.05  0.16  -0.15
# oldest_permit_age                                   0.65  0.09  -0.14
# oldest_permit_age_converted                         1.00  0.22  -0.11
# FCE                                                 0.22  1.00  -0.07
# total                                              -0.11 -0.07   1.00
# income_poverty_level                                0.08 -0.18  -0.07
# white_pct                                          -0.00  0.15  -0.17
# black_pct                                           0.00 -0.15   0.09
# am_indian_ak_native_pct                             0.05  0.02  -0.16
# asian_pct                                          -0.01 -0.02   0.30
# hi_pc_islander_pct                                 -0.04 -0.13   0.01
# other_pct                                          -0.01 -0.05   0.17
# major_sources_in_zip                               -0.08 -0.03   0.24
# fce_per_year                                        0.15 -0.81   0.05
# fce_goal                                            0.99  0.21  -0.12
# fce_difference                                     -0.29  0.87  -0.01
#
#                              income_poverty_level  white_pct  black_pct  \
# zip_code                                    -0.19       0.34      -0.33
# oldest_permit_age                            0.14       0.02      -0.01
# oldest_permit_age_converted                  0.08      -0.00       0.00
# FCE                                         -0.18       0.15      -0.15
# total                                       -0.07      -0.17       0.09
# income_poverty_level                         1.00      -0.69       0.65
# white_pct                                   -0.69       1.00      -0.96
# black_pct                                    0.65      -0.96       1.00
# am_indian_ak_native_pct                      0.06       0.02      -0.08
# asian_pct                                    0.06      -0.24       0.05
# hi_pc_islander_pct                           0.14      -0.21       0.16
# other_pct                                    0.49      -0.45       0.28
# major_sources_in_zip                        -0.03       0.10      -0.11
# fce_per_year                                 0.12      -0.05       0.05
# fce_goal                                     0.09      -0.01       0.01
# fce_difference                              -0.21       0.15      -0.15
#
#                              am_indian_ak_native_pct  asian_pct  \
# zip_code                                        0.36      -0.28
# oldest_permit_age                               0.02      -0.09
# oldest_permit_age_converted                     0.05      -0.01
# FCE                                             0.02      -0.02
# total                                          -0.16       0.30
# income_poverty_level                            0.06       0.06
# white_pct                                       0.02      -0.24
# black_pct                                      -0.08       0.05
# am_indian_ak_native_pct                         1.00      -0.09
# asian_pct                                      -0.09       1.00
# hi_pc_islander_pct                              0.16       0.04
# other_pct                                       0.11       0.03
# major_sources_in_zip                           -0.09      -0.04
# fce_per_year                                   -0.03       0.01
# fce_goal                                        0.05      -0.01
# fce_difference                                 -0.01      -0.02
#
#                              hi_pc_islander_pct  other_pct  \
# zip_code                                  -0.06      -0.07
# oldest_permit_age                          0.02       0.02
# oldest_permit_age_converted               -0.04      -0.01
# FCE                                       -0.13      -0.05
# total                                      0.01       0.17
# income_poverty_level                       0.14       0.49
# white_pct                                 -0.21      -0.45
# black_pct                                  0.16       0.28
# am_indian_ak_native_pct                    0.16       0.11
# asian_pct                                  0.04       0.03
# hi_pc_islander_pct                         1.00       0.23
# other_pct                                  0.23       1.00
# major_sources_in_zip                      -0.02       0.04
# fce_per_year                               0.11       0.04
# fce_goal                                  -0.04      -0.00
# fce_difference                            -0.11      -0.05
#
#                              major_sources_in_zip  fce_per_year  fce_goal  \
# zip_code                                     0.24         -0.16     -0.05
# oldest_permit_age                            0.03          0.19      0.64
# oldest_permit_age_converted                 -0.08          0.15      0.99
# FCE                                         -0.03         -0.81      0.21
# total                                        0.24          0.05     -0.12
# income_poverty_level                        -0.03          0.12      0.09
# white_pct                                    0.10         -0.05     -0.01
# black_pct                                   -0.11          0.05      0.01
# am_indian_ak_native_pct                     -0.09         -0.03      0.05
# asian_pct                                   -0.04          0.01     -0.01
# hi_pc_islander_pct                          -0.02          0.11     -0.04
# other_pct                                    0.04          0.04     -0.00
# major_sources_in_zip                         1.00          0.02     -0.07
# fce_per_year                                 0.02          1.00      0.15
# fce_goal                                    -0.07          0.15      1.00
# fce_difference                               0.00         -0.83     -0.31
#
#                              fce_difference
# zip_code                               0.18
# oldest_permit_age                     -0.24
# oldest_permit_age_converted           -0.29
# FCE                                    0.87
# total                                 -0.01
# income_poverty_level                  -0.21
# white_pct                              0.15
# black_pct                             -0.15
# am_indian_ak_native_pct               -0.01
# asian_pct                             -0.02
# hi_pc_islander_pct                    -0.11
# other_pct                             -0.05
# major_sources_in_zip                   0.00
# fce_per_year                          -0.83
# fce_goal                              -0.31
# fce_difference                         1.00

# %% [markdown]
# # Regressions

# %%
### ODD That a negative relationship shows up -- the longer the permit, the lower the rate of fce_per_year
import statsmodels.formula.api as smf
model = smf.ols("fce_difference ~ oldest_permit_age_converted", data=df)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         fce_difference   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     27.22
# Date:                Fri, 29 Apr 2022   Prob (F-statistic):           3.46e-07
# Time:                        12:58:30   Log-Likelihood:                -449.97
# No. Observations:                 292   AIC:                             903.9
# Df Residuals:                     290   BIC:                             911.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       2.1719      0.496      4.377      0.000       1.195       3.148
# oldest_permit_age_converted    -0.2952      0.057     -5.218      0.000      -0.407      -0.184
# ==============================================================================
# Omnibus:                       10.622   Durbin-Watson:                   1.631
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               19.696
# Skew:                           0.133   Prob(JB):                     5.28e-05
# Kurtosis:                       4.244   Cond. No.                         66.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# pd.qcut(df.years_converted,4)

# %%
(
    ggplot(df.query('years_converted.notna()'), aes(x='years')) + 
        geom_histogram( bins=9) +
        facet_wrap('fce + sar', scales='free_y') + 
        theme(figure_size=(16,9))
)

# %%
(
    ggplot(df, aes(x='years', y='fce + sar')) + 
        geom_point(alpha=.2, size=4) +
        theme(figure_size=(16,9))
)

# pd.crosstab(df.years_converted.quantile(9), df.fce)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 2 rows containing missing values.
# <ggplot: (367435433)>

# %%
model = smf.ols("fce ~ sources", data=df_zip)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    fce   R-squared:                       0.678
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                     849.1
# Date:                Sun, 17 Apr 2022   Prob (F-statistic):          3.00e-101
# Time:                        12:48:33   Log-Likelihood:                -1123.4
# No. Observations:                 405   AIC:                             2251.
# Df Residuals:                     403   BIC:                             2259.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2433      0.279      0.871      0.384      -0.306       0.792
# sources        1.0121      0.035     29.140      0.000       0.944       1.080
# ==============================================================================
# Omnibus:                       89.746   Durbin-Watson:                   2.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              825.507
# Skew:                           0.633   Prob(JB):                    5.54e-180
# Kurtosis:                       9.879   Cond. No.                         11.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_zip.assign(residuals = results.resid,
             residuals_z = results.resid / results.resid.std()
).sort_values(by='residuals').query('fce.notnull()')
# Out:
#      zip_code  sources   fce   sar  violations    total  income_poverty_level  \
# 22    48001.0     17.0   1.0  10.0         4.0  11818.0                   9.9
# 19    48701.0     17.0   2.0  32.0        54.0   1378.0                  17.4
# 17    48071.0     18.0   6.0  19.0         7.0  29964.0                  13.6
# 27    49022.0     16.0   5.0  11.0         8.0  30927.0                  32.6
# 20    49424.0     17.0   7.0  18.0         7.0  48456.0                   9.0
# ..        ...      ...   ...   ...         ...      ...                   ...
# 80    49660.0      9.0  22.0  32.0         4.0  12915.0                   9.5
# 0     49735.0     46.0  60.0  76.0         9.0  19372.0                  14.1
# 6     49464.0     23.0  40.0  44.0         9.0  28804.0                   4.1
# 8     49646.0     21.0  47.0  47.0         3.0   8157.0                  16.7
# 622       NaN      NaN   2.0   2.0         NaN      NaN                   NaN
#
#      white_pct  black_pct  am_indian_ak_native_pct  asian_pct  \
# 22        97.0        0.1                      0.6        0.6
# 19        89.0        1.0                      0.3        0.5
# 17        80.8        8.5                      0.4        5.8
# 27        42.3       52.5                      0.1        0.2
# 20        77.3        2.2                      0.3        7.3
# ..         ...        ...                      ...        ...
# 80        88.7        4.2                      2.0        0.6
# 0         95.2        0.8                      0.3        0.6
# 6         91.3        0.9                      0.3        4.1
# 8         95.9        0.5                      0.8        0.7
# 622        NaN        NaN                      NaN        NaN
#
#      hi_pc_islander_pct  other_pct  residuals  residuals_z
# 22                  0.1        1.6 -16.449014    -4.238264
# 19                  0.0        9.3 -15.449014    -3.980604
# 17                  0.0        4.5 -12.461114    -3.210739
# 27                  0.1        4.9 -11.436914    -2.946843
# 20                  0.0       12.9 -10.449014    -2.692300
# ..                  ...        ...        ...          ...
# 80                  0.1        4.4  12.647788     3.258838
# 0                   0.0        3.1  13.200077     3.401141
# 6                   0.0        3.3  16.478384     4.245832
# 8                   0.0        2.1  25.502585     6.571014
# 622                 NaN        NaN        NaN          NaN
#
# [406 rows x 15 columns]

# %%
model = smf.ols("sources ~ black_pct", data=df_zip)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sources   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     5.358
# Date:                Sat, 02 Apr 2022   Prob (F-statistic):             0.0210
# Time:                        00:04:42   Log-Likelihood:                -1826.3
# No. Observations:                 606   AIC:                             3657.
# Df Residuals:                     604   BIC:                             3665.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.3383      0.222     19.562      0.000       3.903       4.774
# black_pct      0.0250      0.011      2.315      0.021       0.004       0.046
# ==============================================================================
# Omnibus:                      413.276   Durbin-Watson:                   0.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5160.524
# Skew:                           2.920   Prob(JB):                         0.00
# Kurtosis:                      16.049   Cond. No.                         22.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df.sort_values("fce_per_year",ascending=False).head(20)
# Out:
#          id                                             name_x  zip_code  \
# 371   M4780                                   ROUSH INDUSTRIES   48150.0
# 1897  B1976                       J.B. SIMS GENERATING STATION   49417.0
# 2741  A2402                         ACCESS BUSINESS GROUP, LLC   49355.0
# 1947  B6356                                   THE WORDEN GROUP   49423.0
# 2587  P0796    UPPER MICHIGAN ENERGY RESOURCES -A.J. MIHM G.S.   49849.0
# 2586  P0797  UPPER MICHIGAN ENERGY RESOURCES -F.D. KUESTER ...   49849.0
# 719   B2329                           PAR STERILE PRODUCTS LLC   48307.0
# 1607  B6519                            W. R. GRACE & CO.-CONN.   49090.0
# 833   B1950                                 CLINTON RIVER WRRF   48342.0
# 2603  B1855                                   DUNN PAPER, INC.   49858.0
# 863   B2881         US ENERGY DISTRIBUTION LLC - NOVI TERMINAL   48375.0
# 2268  N6279   LAMBDA ENERGY RESOURCES LLC - RICCI 19 (BLUE LK)   49646.0
# 2568  N6297                             PAYNE & DOLAN INC  C25   49837.0
# 1257  N7688                       DICASTAL NORTH AMERICA, INC.   48838.0
# 1427  N6261                  SUMMIT POLYMERS,  INC.  PLANT ONE   49002.0
# 1583  B7244                                JBS PLAINWELL, INC.   49080.0
# 2688  N7519                                    ASH STEVENS LLC   48193.0
# 2195  N7679                       RACK PROCESSING MICHIGAN LCC   49548.0
# 23    B6481    ANR PIPELINE COMPANY - CAPAC COMPRESSOR STATION   48014.0
# 1939  P0087                   LG ENERGY SOLUTION MICHIGAN INC.   49423.0
#
#            county                                       full_address  \
# 371         WAYNE                        36630 COMMERCE, LIVONIA, MI
# 1897       OTTAWA                 1231 N. THIRD ST., GRAND HAVEN, MI
# 2741         KENT                          7575 E FULTON RD, ADA, MI
# 1947       OTTAWA                       199 E. 17TH ST., HOLLAND, MI
# 2587       BARAGA                       16017 SARYA ROAD, PELKIE, MI
# 2586    MARQUETTE                  80 EAGLE MILLS ROAD, NEGAUNEE, MI
# 719       OAKLAND                    870  PARKDALE RD, ROCHESTER, MI
# 1607    VAN BUREN                 1421 KALAMAZOO ST, SOUTH HAVEN, MI
# 833       OAKLAND                     155 N OPDYKE ROAD, PONTIAC, MI
# 2603    MENOMINEE                    144 FIRST STREET, MENOMINEE, MI
# 863       OAKLAND                 40600 GRAND RIVER AVENUE, NOVI, MI
# 2268     KALKASKA                         SUNSET TRAIL, KALKASKA, MI
# 2568        DELTA  C25 PORTABLE ASPHALT PLANT  #218-97C, GLADSTON...
# 1257     MONTCALM                     1 DICASTAL DR., GREENVILLE, MI
# 1427    KALAMAZOO                     4750 EXECUTIVE DR, PORTAGE, MI
# 1583      ALLEGAN                      11 11TH STREET, PLAINWELL, MI
# 2688        WAYNE                        18655 KRAUSE, RIVERVIEW, MI
# 2195         KENT                     3513 LOUSMA DR SE, WYOMING, MI
# 23    SAINT CLAIR                     4876  KETTLEHUT RD., CAPAC, MI
# 1939      ALLEGAN              875 E 48TH ST (1 LG WAY), HOLLAND, MI
#
#                               geometry  fce  sar  violations    total  ...  \
# 371   [-83.40355790000001, 42.3725279]  4.0  5.0         0.0  25666.0  ...
# 1897  [-86.23431389999999, 43.0703422]  6.0  6.0         1.0  31037.0  ...
# 2741         [-85.4882275, 42.9579966]  4.0  5.0         0.0      NaN  ...
# 1947         [-86.0977906, 42.7818765]  2.0  2.0         0.0  41484.0  ...
# 2587         [-88.6166085, 46.7936854]  2.0  2.0         0.0  12118.0  ...
# 2586         [-87.5107056, 46.5130831]  2.0  2.0         0.0  12118.0  ...
# 719   [-83.11913170000001, 42.6872164]  4.0  5.0         0.0  43201.0  ...
# 1607  [-86.27303189999999, 42.3848496]  2.0  2.0         0.0  14127.0  ...
# 833   [-83.25454400000001, 42.6389509]  3.0  3.0         1.0  16645.0  ...
# 2603  [-87.59789169999999, 45.0985895]  3.0  3.0         3.0  11516.0  ...
# 863          [-83.4473478, 42.4768226]  2.0  1.0         1.0  21844.0  ...
# 2268           [-85.004351, 44.640885]  3.0  2.0         0.0   8157.0  ...
# 2568  [-87.02180489999999, 45.8527435]  2.0  2.0         0.0   9251.0  ...
# 1257         [-85.2353479, 43.1933539]  6.0  6.0         7.0  18184.0  ...
# 1427  [-85.53243169999999, 42.2261421]  2.0  2.0         0.0  20510.0  ...
# 1583  [-85.64814349999999, 42.4230459]  1.0  1.0         0.0  15708.0  ...
# 2688  [-83.17319049999999, 42.1720952]  2.0  2.0         0.0  15208.0  ...
# 2195  [-85.6578564, 42.90007070000001]  3.0  3.0         0.0  33474.0  ...
# 23           [-82.9483376, 43.0380328]  4.0  4.0         0.0   4097.0  ...
# 1939         [-86.0680318, 42.7554419]  2.0  0.0         2.0  41484.0  ...
#
#       black_pct  am_indian_ak_native_pct  asian_pct  hi_pc_islander_pct  \
# 371         3.9                      0.1        2.3                 0.0
# 1897        0.4                      0.3        0.9                 0.0
# 2741        NaN                      NaN        NaN                 NaN
# 1947        3.4                      0.5        2.5                 0.0
# 2587        0.8                      0.4        0.8                 0.0
# 2586        0.8                      0.4        0.8                 0.0
# 719         4.5                      0.2       11.9                 0.0
# 1607        6.9                      0.2        1.8                 0.0
# 833        65.3                      0.2        0.9                 0.0
# 2603        0.4                      0.3        0.4                 0.0
# 863         6.6                      0.4       24.7                 0.1
# 2268        0.5                      0.8        0.7                 0.0
# 2568        0.1                      1.2        0.2                 0.0
# 1257        0.5                      0.1        0.4                 0.2
# 1427        4.9                      0.5        1.7                 0.0
# 1583        0.9                      0.3        0.0                 0.0
# 2688        6.6                      0.1        4.0                 0.0
# 2195       10.3                      0.8        4.5                 0.1
# 23          0.2                      0.1        0.0                 0.0
# 1939        3.4                      0.5        2.5                 0.0
#
#       other_pct    srn    approved     years years_converted  fce_per_year
# 371         2.6  M4780  2022-01-21  0.191653        0.191653     20.871000
# 1897        2.7  B1976  2021-11-05  0.402472        0.402472     14.907857
# 2741        NaN  A2402  2021-11-16  0.372355        0.372355     10.742426
# 1947        9.0  B6356  2022-01-20  0.194391        0.194391     10.288521
# 2587        3.0  P0796  2022-01-18  0.199867        0.199867     10.006644
# 2586        3.0  P0797  2022-01-18  0.199867        0.199867     10.006644
# 719         3.0  B2329  2021-09-30  0.501037        0.501037      7.983443
# 1607        7.5  B6519  2021-12-20  0.279267        0.279267      7.161618
# 833         7.2  B1950  2021-10-22  0.440803        0.440803      6.805761
# 2603        2.9  B1855  2021-10-21  0.443541        0.443541      6.763750
# 863         4.6  B2881  2021-12-13  0.298432        0.298432      6.701697
# 2268        2.1  N6279  2021-10-15  0.459968        0.459968      6.522187
# 2568        3.7  N6297  2021-11-18  0.366880        0.366880      5.451381
# 1257        2.9  N7688  2021-02-16  1.119804        1.119804      5.358081
# 1427        5.1  N6261  2021-11-15  0.375093        0.375093      5.332007
# 1583        4.4  B7244  2022-01-18  0.199867        0.199867      5.003322
# 2688        2.3  N7519  2021-10-14  0.462706        0.462706      4.322396
# 2195       12.2  N7679  2021-07-01  0.750187        0.750187      3.999005
# 23          7.6  B6481  2021-03-31  1.002074        1.002074      3.991721
# 1939        9.0  P0087  2021-09-16  0.539368        0.539368      3.708046
#
# [20 rows x 22 columns]
